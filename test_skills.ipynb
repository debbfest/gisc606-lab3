# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import rioxarray as rxr 
import matplotlib.pyplot as plt
import earthpy.plot as ep

import earthpy as et
import earthpy.plot as ep

# %%
from rasterio.plot import plotting_extent

# %%
et.data.get_data("colorado-flood")
os.chdir(os.path.join(et.io.HOME, 'earth-analytics', 'data'))

# %%
hillshade_path = os.path.join("colorado-flood", "spatial", "boulder-leehill-rd", "pre-flood", "lidar", "pre_DTM_hill.tif")

# %%
hillshade = rxr.open_rasterio(hillshade_path)

# %%
ep.plot_bands(hillshade,
              title="Challenge 1: Lidar Digital Terrain Model (DTM) \n Overlayed on Top of Hillshade",
              cmap="gray")

plt.show()

# %%
lidar_dtm_path = os.path.join("colorado-flood", "spatial", "boulder-leehill-rd", "pre-flood", "lidar", "pre_DTM.tif")
dtm = rxr.open_rasterio(lidar_dtm_path)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ep.plot_bands(hillshade,
              ax=ax,
              title="Challenge 2: Lidar Digital Terrain Model (DTM) \n Overlayed on Top of Hillshade",
              cmap="gray")

plt.show()

# %%
extent = plotting_extent(hillshade[0], hillshade.rio.transform())

fig, ax = plt.subplots(figsize=(10, 8))
ep.plot_bands(hillshade,
              ax=ax,
              title="Challenge 3: Lidar Digital Terrtain Model (DTM) \n Overlayed on Top of Hillshade",
              cmap="gray",
              extent=extent)

ep.plot_bands(dtm,
              ax=ax,
              cmap='cividis',
              alpha=0.75,  
              extent=extent)

site_boundary.plot(ax=ax, color='none', edgecolor='red', linewidth=2)

plt.show()

# %%
pre_dtm_path = os.path.join("colorado-flood", "spatial", "boulder-leehill-rd", "pre-flood", "lidar", "pre_DTM.tif")
pre_dtm = rxr.open_rasterio(pre_dtm_path)

post_dtm_path = os.path.join("colorado-flood", "spatial", "boulder-leehill-rd", "post-flood", "lidar", "post_DTM.tif")
post_dtm = rxr.open_rasterio(post_dtm_path)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 10))

ep.plot_bands(pre_dtm,
              ax=ax1,
              title="Pre-Flood DTM",
              extent=post_dtm_extent)  # Use the extent of post-flood DTM

ep.plot_bands(post_dtm,
              ax=ax2,
              title="Post-Flood DTM",
              extent=post_dtm_extent)

plt.suptitle("Challenge 4: Pre Flood DTM")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()

#Can't figure out why the first DEM isn't showing up. Sad times

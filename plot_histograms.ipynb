# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import rioxarray as rxr
import earthpy as et

os.chdir(os.path.join(et.io.HOME, "earth-analytics", "data"))

sns.set(font_scale=1.5, style="whitegrid")

# %%
lidar_dem_path = os.path.join("colorado-flood", "spatial", "boulder-leehill-rd", "pre-flood", "lidar", "pre_DTM.tif")

lidar_dem_im = rxr.open_rasterio(lidar_dem_path)

lidar_dem_im.shape
# Out:
# (1, 2000, 4000)

# %%
f, ax = plt.subplots(figsize=(10,6))

lidar_dem_im.plot.hist(ax=ax, color="teal", bins=50)

ax.set(title="Distribution of Lidar DEM Elevation Values", xlabel="Elevation (meters)", ylabel="Frequency")

plt.show()

# %%
lidar_dem_im = rxr.open_rasterio(lidar_dem_path, masked=True)

f, ax = plt.subplots(figsize=(10,6))

lidar_dem_im.plot.hist(ax=ax, color="teal", bins=30)

plt.show()

# %%
lidar_dem_im = rxr.open_rasterio(lidar_dem_path, masked=True)

f, ax = plt.subplots(figsize=(10,6))

lidar_dem_im.plot.hist(ax=ax, color=#3B8EEA, bins=30)

plt.show()
# Out:
#   Cell In[5], line 7
#     plt.show()
#               ^
# SyntaxError: incomplete input

# %%
f, ax = plt.subplots(figsize=(10,6))

lidar_dem_im.plot.hist(ax=ax, color="dark pink", bins=[1600, 1800, 2000, 2100])

ax.set(title="Distribution of lidar DEM Elevation values")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 f, ax = plt.subplots(figsize=(10,6))
# ----> 3 lidar_dem_im.plot.hist(ax=ax, color="dark pink", bins=[1600, 1800, 2000, 2100])
#       5 ax.set(title="Distribution of lidar DEM Elevation values")
#       7 plt.show()
#
# File ~/.python/current/lib/python3.10/site-packages/xarray/plot/accessor.py:54, in DataArrayPlotAccessor.hist(self, *args, **kwargs)
#      50 @functools.wraps(dataarray_plot.hist)
#      51 def hist(
#      52     self, *args, **kwargs
#      53 ) -> tuple[np.ndarray, np.ndarray, BarContainer | Polygon]:
# ---> 54     return dataarray_plot.hist(self._da, *args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:704, in hist(darray, figsize, size, aspect, ax, xincrease, yincrease, xscale, yscale, xticks, yticks, xlim, ylim, *args, **kwargs)
# ...

# %%
f, ax = plt.subplots(figsize=(10,6))

lidar_dem_im.plot.hist(ax=ax, color="pink", bins=[1600, 1800, 2000, 2100])

ax.set(title="Distribution of lidar DEM Elevation values")

plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))

lidar_dem_im.plot.hist(ax=ax, color="blue", bins=[1600, 1800, 2000, 2100])

ax.set(title="Distribution of lidar DEM Elevation values")

plt.show()
